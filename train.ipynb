# %% [markdown]
# # Imports

# %%
import numpy as np
#import cv2
import random
import time

from collections import deque
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, DQN, A2C

# %%
import copy
from stable_baselines3 import DQN
import os
from sb3_contrib import MaskablePPO

from sb3_contrib.common.maskable.evaluation import evaluate_policy

from sb3_contrib.common.maskable.utils import get_action_masks

from sb3_contrib.common.maskable.callbacks import MaskableEvalCallback

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="gymnasium")

# %%
from env import Environment
# Out:
# /home/muhammadelmahdy/anaconda3/envs/dispatcher_env/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:271: UserWarning: Your observation couriers has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /home/muhammadelmahdy/anaconda3/envs/dispatcher_env/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:271: UserWarning: Your observation orders has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# # Creating an instance

# %%
env=Environment()

# %%
env.reset()
# Out:
# ({'orders': array([[ 5.6800000e+02,  4.5866360e+07,  1.7453672e+08,  4.5856520e+07,
#            1.7450744e+08],
#          [ 5.6900000e+02,  4.5890760e+07,  1.7457333e+08,  4.5888080e+07,
#            1.7456171e+08],
#          [ 5.7000000e+02,  4.5894568e+07,  1.7458938e+08,  4.5897884e+07,
#            1.7458947e+08],
#          ...,
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00],
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00],
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00]], dtype=float32),
#   'couriers': array([[ 2.0000000e+00,  3.0000000e+00,  4.5896340e+07,  1.7455587e+08,
#            2.0000000e+00],
#          [ 1.3000000e+01,  7.0000000e+00,  4.5851428e+07,  1.7455411e+08,
#            4.0000000e+00],
#          [ 1.6000000e+01,  9.0000000e+00,  4.5876832e+07,  1.7463725e+08,
#            1.0000000e+00],
#          ...,
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00],
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00],
#          [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, -1.0000000e+00,
#           -1.0000000e+00]], dtype=float32),
#   'system': array([841, 548])},
#  {})

# %%
models_dir = '/home/muhammadelmahdy/rl_dispatcher/models/new-2'
logdir = '/home/muhammadelmahdy/rl_dispatcher/logs/new-2'
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
model_PPO = MaskablePPO("MultiInputPolicy", env, gamma=0.9, seed=32, verbose=1, tensorboard_log=logdir)

#gae_lambda=0.95,
#model_PPO = MaskablePPO("MultiInputPolicy", env, gamma=0.95, seed=32, verbose=1, tensorboard_log=logdir, learning_rate=5e-3)
TIMESTEPS = 10000
MAX_ITERATIONS = 150 # Set a maximum number of iterations for training

iters = 0
while iters < MAX_ITERATIONS:
    iters += 1
    
    print('iteration number: ',iters)
    model_PPO.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"NewRunnn2")
    model_PPO.save(f"{models_dir}/{TIMESTEPS*iters}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# iteration number:  1
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 853      |
# |    ep_rew_mean     | 0.388    |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 129      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 848         |
# |    ep_rew_mean          | 0.405       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 2           |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021019824 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.3        |
# |    explained_variance   | -9.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.131      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0879     |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 0.437       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 3           |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.025002804 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.26       |
# |    explained_variance   | -10.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.133      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0985     |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 828        |
# |    ep_rew_mean          | 0.421      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 4          |
# |    time_elapsed         | 785        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02293358 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.25      |
# |    explained_variance   | -11.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.103     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0919    |
# |    value_loss           | 0.00166    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 820        |
# |    ep_rew_mean          | 0.438      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 5          |
# |    time_elapsed         | 1005       |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02162443 |
# |    clip_fraction        | 0.34       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.24      |
# |    explained_variance   | -12.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.128     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0901    |
# |    value_loss           | 0.0011     |
# ----------------------------------------
# iteration number:  2
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 826      |
# |    ep_rew_mean     | 0.423    |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 134      |
# |    total_timesteps | 12288    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 849        |
# |    ep_rew_mean          | 0.424      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 2          |
# |    time_elapsed         | 371        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.03181626 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.26      |
# |    explained_variance   | -8.6       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.133     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0982    |
# |    value_loss           | 0.00112    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 0.442       |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 3           |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.037986092 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.28       |
# |    explained_variance   | -9.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.12       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0952     |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | 0.459      |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 4          |
# |    time_elapsed         | 877        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03176605 |
# |    clip_fraction        | 0.434      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.39      |
# |    explained_variance   | -9.66      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0927    |
# |    value_loss           | 0.00118    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 974         |
# |    ep_rew_mean          | 0.477       |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 5           |
# |    time_elapsed         | 1155        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.037729703 |
# |    clip_fraction        | 0.506       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.47       |
# |    explained_variance   | -6.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.125      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.11       |
# |    value_loss           | 0.000695    |
# -----------------------------------------
# iteration number:  3
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 0.49     |
# | time/              |          |
# |    fps             | 10       |
# |    iterations      | 1        |
# |    time_elapsed    | 198      |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 0.509       |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 2           |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.037283566 |
# |    clip_fraction        | 0.482       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | -4.92       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.123      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.105      |
# |    value_loss           | 0.000458    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 0.521       |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 3           |
# |    time_elapsed         | 817         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.043181006 |
# |    clip_fraction        | 0.565       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.59       |
# |    explained_variance   | -8.79       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.15       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.114      |
# |    value_loss           | 0.00061     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 0.521       |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 4           |
# |    time_elapsed         | 1139        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.036457695 |
# |    clip_fraction        | 0.497       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.57       |
# |    explained_variance   | -8.77       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.14       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.105      |
# |    value_loss           | 0.000444    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | 0.545      |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 5          |
# |    time_elapsed         | 1479       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04185171 |
# |    clip_fraction        | 0.498      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.52      |
# |    explained_variance   | -6.52      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.119     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.101     |
# |    value_loss           | 0.000339   |
# ----------------------------------------
# iteration number:  4
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 0.562    |
# | time/              |          |
# |    fps             | 8        |
# |    iterations      | 1        |
# |    time_elapsed    | 255      |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 2           |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.033343993 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.62       |
# |    explained_variance   | -9.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.142      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.096      |
# |    value_loss           | 0.000179    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 3           |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.039228503 |
# |    clip_fraction        | 0.49        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.42       |
# |    explained_variance   | -10.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.119      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0919     |
# |    value_loss           | 0.000187    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.34e+03   |
# |    ep_rew_mean          | 0.601      |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 4          |
# |    time_elapsed         | 1323       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03533449 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.63      |
# |    explained_variance   | -6.15      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.138     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0944    |
# |    value_loss           | 5.52e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | 0.63        |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 5           |
# |    time_elapsed         | 1693        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.030008173 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.73       |
# |    explained_variance   | -4.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.104      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0838     |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# iteration number:  5
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | 0.63     |
# | time/              |          |
# |    fps             | 7        |
# |    iterations      | 1        |
# |    time_elapsed    | 276      |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.47e+03    |
# |    ep_rew_mean          | 0.655       |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 2           |
# |    time_elapsed         | 658         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.041117325 |
# |    clip_fraction        | 0.549       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.85       |
# |    explained_variance   | -5.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.128      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.107      |
# |    value_loss           | 4.49e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.47e+03    |
# |    ep_rew_mean          | 0.655       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 3           |
# |    time_elapsed         | 1034        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.032594863 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | -3.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0722     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0845     |
# |    value_loss           | 9.24e-05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.53e+03  |
# |    ep_rew_mean          | 0.682     |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 4         |
# |    time_elapsed         | 1428      |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0338288 |
# |    clip_fraction        | 0.495     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.86     |
# |    explained_variance   | -2.57     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.122    |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.1      |
# |    value_loss           | 2.69e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.6e+03    |
# |    ep_rew_mean          | 0.705      |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 5          |
# |    time_elapsed         | 1823       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03395619 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.85      |
# |    explained_variance   | -8.15      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.116     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0927    |
# |    value_loss           | 4.89e-05   |
# ----------------------------------------
# iteration number:  6
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | 0.705    |
# | time/              |          |
# |    fps             | 6        |
# |    iterations      | 1        |
# |    time_elapsed    | 295      |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 0.734       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 2           |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.031337023 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.88       |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0959     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0848     |
# |    value_loss           | 6.07e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 0.734       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 3           |
# |    time_elapsed         | 1087        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.039540723 |
# |    clip_fraction        | 0.57        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | -2.53       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.129      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.116      |
# |    value_loss           | 2e-05       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.73e+03    |
# |    ep_rew_mean          | 0.761       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 4           |
# |    time_elapsed         | 1491        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.031110642 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.88       |
# |    explained_variance   | -0.742      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.127      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.078      |
# |    value_loss           | 9.62e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.73e+03   |
# |    ep_rew_mean          | 0.761      |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 5          |
# |    time_elapsed         | 1887       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.04054366 |
# |    clip_fraction        | 0.568      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.93      |
# |    explained_variance   | -4.54      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 9.46e-06   |
# ----------------------------------------
# iteration number:  7
# Logging to /home/muhammadelmahdy/rl_dispatcher/logs/new-2/NewRunnn2_0
